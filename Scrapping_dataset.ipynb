# %% [markdown]
# ## **Scrapping Data**

# %%
# python -m pip install google-play-scraper
# Mengimpor pustaka google_play_scraper untuk mengakses ulasan dan informasi aplikasi dari Google Play Store.
import pandas as pd
from google_play_scraper import app, reviews, Sort, reviews_all

# %%
scrapreview = reviews_all(
    "com.mobile.legends",
    lang="id",
    country="id",
    sort=Sort.MOST_RELEVANT,
    count=3000,
)

# %%
df = pd.DataFrame(scrapreview)
df.head(-10)
# Out:
#                                     reviewId         userName  \
# 0       2e2f03a9-0023-433e-8c4c-b2e60d0def8d  Pengguna Google
# 1       b4156d99-2131-49f5-b52e-f35191b5a917  Pengguna Google
# 2       7dde871d-b331-4f52-9237-3b61ca1b8adb  Pengguna Google
# 3       6652f00e-a706-482b-9400-0932dcf5a886  Pengguna Google
# 4       1bd93463-93e5-4945-9be0-5c8648048259  Pengguna Google
# ...                                      ...              ...
# 211485  b66d5fa4-87d1-4a4b-9238-992937daca96  Pengguna Google
# 211486  210d225e-e36c-464b-9f80-dc608a317b2b  Pengguna Google
# 211487  281719c1-0489-4c9c-8a3a-6c4e413d8519  Pengguna Google
# 211488  499c4fcc-3a48-4f52-ab92-8d68e7e33b78  Pengguna Google
# 211489  8090c4e9-a719-47d7-955f-59eab9e126ed  Pengguna Google
#
#                                                 userImage  \
# 0       https://play-lh.googleusercontent.com/EGemoI2N...
# 1       https://play-lh.googleusercontent.com/EGemoI2N...
# 2       https://play-lh.googleusercontent.com/EGemoI2N...
# 3       https://play-lh.googleusercontent.com/EGemoI2N...
# 4       https://play-lh.googleusercontent.com/EGemoI2N...
# ...                                                   ...
# 211485  https://play-lh.googleusercontent.com/EGemoI2N...
# 211486  https://play-lh.googleusercontent.com/EGemoI2N...
# 211487  https://play-lh.googleusercontent.com/EGemoI2N...
# 211488  https://play-lh.googleusercontent.com/EGemoI2N...
# 211489  https://play-lh.googleusercontent.com/EGemoI2N...
#
#                                                   content  score  \
# 0       Saya ingin menyampaikan keluhan serius terkait...      2
# 1       Matchmaking tidak adil. Penysuaian antara skil...      1
# 2       Tolong cek lagi optimasi jaringan/servernya sa...      1
# 3       game ini terlalu kuat makan jaringan susah bua...      5
# 4       Sebenarnya udah bagus banget, dari Matchmaking...      4
# ...                                                   ...    ...
# 211485  Jangan update Mulu bug nya aja ga di perbaiki ...      1
# 211486  Sebelum update: lancar gak ada masalah Setelah...      1
# 211487  Game apaan ini ngasih lawan yang sepadan lah, ...      2
# 211488  Game nya si bagus ,tpi mikirlah min musuh dika...      1
# 211489  masih samaa tentang masalah signal yang lag pa...      3
#
#         thumbsUpCount reviewCreatedVersion                  at replyContent  \
# 0                   2         2.1.95.12066 2026-08-25 18:10:38          NaN
# 1                   1         2.1.95.12066 2026-08-27 23:20:59          NaN
# 2                   4         2.1.95.12066 2026-08-28 06:09:06          NaN
# 3                   1         2.1.95.12066 2026-08-28 00:07:14          NaN
# 4                   2         2.1.95.12053 2026-08-25 15:50:38          NaN
# ...               ...                  ...                 ...          ...
# 211485              0          1.7.44.8111 2023-02-16 21:51:04          NaN
# 211486              0                  NaN 2023-01-15 20:50:29          NaN
# 211487              0          1.7.44.8111 2023-02-11 17:09:14          NaN
# 211488              0          1.6.95.7592 2022-07-14 17:22:07          NaN
# 211489              0                  NaN 2019-08-28 10:36:20          NaN
#
#        repliedAt    appVersion
# 0            NaT  2.1.95.12066
# 1            NaT  2.1.95.12066
# 2            NaT  2.1.95.12066
# 3            NaT  2.1.95.12066
# 4            NaT  2.1.95.12053
# ...          ...           ...
# 211485       NaT   1.7.44.8111
# 211486       NaT           NaN
# 211487       NaT   1.7.44.8111
# 211488       NaT   1.6.95.7592
# 211489       NaT           NaN
#
# [211490 rows x 11 columns]

# %%
df.to_csv("Ulasan_APK_Mobile_Legends.csv")
